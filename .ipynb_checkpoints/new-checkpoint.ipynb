# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("whitegrid")

import pandas as pd
pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', 120)
pd.set_option('max_colwidth', None)

from foods.meals import molly_meals, paps_meals, fabian_meals, test_meals
from foods.dashboard import read_raw, find_food, calc_nuts, make_dashboard, make_nutrient_graphs

# %load_ext autoreload
# %autoreload 2

# %%
def str_to_numeric(df):
    cols = ['calories', 'fat', 'carbs', 'sugar', 'fiber', 'protein']
    df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
    return df

def str_to_lower(df):
    cols = df.columns[df.dtypes.eq('object')]
    df[cols] = df[cols].applymap(str.lower)
    return df

columns = {
    'Name': 'ingredient',
    'Category': 'category',
    'Matrix unit': 'units',
    'Energy, kilocalories (kcal)': 'calories',
    'Fat, total (g)': 'fat',
    'Carbohydrates, available (g)': 'carbs',
    'Protein (g)': 'protein',
    'Sugars (g)': 'sugar',
    'Dietary fibres (g)': 'fiber',
}

path = './data/Swiss-food-composition-database-V6.1.xlsx'
    
foods = (
    pd.read_excel(path, skiprows=2, usecols=columns)
    .rename(columns=columns)
    .pipe(str_to_numeric)
    .pipe(str_to_lower)
)

print(foods.shape)
foods.head()
# Out:
# (1018, 9)
#                     ingredient                                       category  \
# 0                    agar agar             various/gelling and binding agents
# 1                  agave syrup                    sweets/sugar and sweeteners
# 2                       almond               nuts, seeds and oleaginous fruit
# 3  almond, dry roasted, salted  savoury snacks/salted nuts, seeds and kernels
# 4      almond, roasted, salted  savoury snacks/salted nuts, seeds and kernels
#
#                      units  calories   fat  carbs  sugar  fiber  protein
# 0  per 100g edible portion       160   0.2    0.0    NaN   74.1      2.4
# 1  per 100g edible portion       293   0.0   73.1    NaN    0.0      0.2
# 2  per 100g edible portion       593  49.9    4.0    3.9   13.0     25.5
# 3  per 100g edible portion       634  52.1   10.3    4.9   10.9     25.4
# 4  per 100g edible portion       649  55.2    7.2    4.6   10.5     25.6

# %%
def find_item(regex, cat=False):
    if not cat:
        subset = foods.ingredient.str.contains(regex)
    else:
        subset = foods.category.str.contains(regex)
    return foods[subset]
        

find_item('chick')
# Out:
#                                                                                            ingredient  \
# 186                                                                        chicken, breast (cut), raw
# 187                                                       chicken, breast, without skin, raw (france)
# 188                                                  chicken, breast, without skin, raw (switzerland)
# 189                                                          chicken, breast, with skin, raw (france)
# 190                                                     chicken, breast, with skin, raw (switzerland)
# 191                  chicken, brest (schnitzel, ground), pan fried (without addition of fat and salt)
# 192                                                                   chicken egg, whole, hard boiled
# 193                                                          chicken, leg, without skin, raw (france)
# 194                                                     chicken, leg, without skin, raw (switzerland)
# 195                                                                      chicken, leg, with skin, raw
# 196                                                             chicken, leg, with skin, raw (france)
# 197                                                        chicken, leg, with skin, raw (switzerland)
# 198                                chicken, leg with skin, roasted (without addition of fat and salt)
# 199                                                                    chicken, whole, with skin, raw
# 200                              chicken, whole with skin, roasted (without addition of fat and salt)
# 201                                               chickpea, cooked (without addition of fat and salt)
# 202                                                                                   chickpea, dried
# 508  minced meat (average of beef, veal, pork, chicken), pan fried (without addition of fat and salt)
# 509                                           minced meat (average of beef, veal, pork, chicken), raw
# 716                                                                riz casimir with chicken, prepared
#
#                                                                                category  \
# 186                                                              meat and offal/poultry
# 187                                                              meat and offal/poultry
# 188                                                              meat and offal/poultry
# 189                                                              meat and offal/poultry
# 190                                                              meat and offal/poultry
# 191                                                              meat and offal/poultry
# 192                                                                                eggs
# 193                                                              meat and offal/poultry
# 194                                                              meat and offal/poultry
# 195                                                              meat and offal/poultry
# 196                                                              meat and offal/poultry
# 197                                                              meat and offal/poultry
# 198                                                              meat and offal/poultry
# 199                                                              meat and offal/poultry
# 200                                                              meat and offal/poultry
# 201                                         cereal products, pulses and potatoes/pulses
# 202                                         cereal products, pulses and potatoes/pulses
# 508                                                                      meat and offal
# 509  meat and offal/veal;meat and offal/beef;meat and offal/pork;meat and offal/poultry
# 716                                                prepared dishes/other savoury dishes
#
#                        units  calories   fat  carbs  sugar  fiber  protein
# 186  per 100g edible portion       105   1.2    0.4    0.0    0.0     23.1
# 187  per 100g edible portion       109   0.9    0.0    0.0    0.0     25.2
# 188  per 100g edible portion       107   1.0    0.0    0.0    0.0     24.6
# 189  per 100g edible portion       126   3.3    0.0    0.0    0.0     24.0
# 190  per 100g edible portion       152   6.5    0.0    0.0    0.0     23.3
# 191  per 100g edible portion       131   1.5    0.4    0.0    0.0     28.9
# 192  per 100g edible portion       157  11.4    0.3    0.3    0.0     13.2
# 193  per 100g edible portion       121   4.3    0.0    0.0    0.0     20.6
# 194  per 100g edible portion       135   6.2    0.0    0.0    0.0     19.7
# 195  per 100g edible portion       184  12.6    0.0    0.0    0.0     17.6
# 196  per 100g edible portion       145   7.5    0.0    0.0    0.0     19.4
# 197  per 100g edible portion       163  10.2    0.0    0.0    0.0     17.9
# 198  per 100g edible portion       218  13.6    0.0    0.0    0.0     23.9
# 199  per 100g edible portion       168  10.3    0.0    0.0    0.0     18.8
# 200  per 100g edible portion       224  13.7    0.0    0.0    0.0     25.1
# 201  per 100g edible portion       131   2.0   17.7    1.0    6.2      7.4
# 202  per 100g edible portion       327   4.9   44.3    2.4   15.5     18.6
# 508  per 100g edible portion       181   7.9    0.0    0.0    0.0     27.4
# 509  per 100g edible portion       143   6.2    0.0    0.0    0.0     21.6
# 716  per 100g edible portion       127   3.4   16.1    3.4    1.1      7.6

# %%
meals = {

    'Lunch': {
        'coconut fat': 0.2,
        'scrambled eggs, prepared': 2.4,
        'mushroom, stewed (without addition of fat and salt)': 0.5,
        'spinach, steamed (without addition of salt)': 0.5,
        
        'iceberg lettuce, raw': 0.5,
        'avocado, fresh': 1.6,
        'bell pepper, red, raw': 0.5,
        'seeds, kernels, nuts (average), unsalted': 0.2,
        'olive oil': 0.2,
        'vinegar': 0.1,
    },
    
    'Snack': {
        'coconut fat': 0.2,
        'cocoa powder': 0.05,
        'coffee, black, no sugar added': 1,
    },
    
#     'Supper': {
        
#     }
}

# %%
def get_meal_data(meal):

    # Grams data
    data = (foods[foods.ingredient.isin(meal)].copy()
            .set_index('ingredient')
            .drop(['units', 'category', 'calories', 'sugar'], axis=1))
    portion = data.index.map(meal)
    grams = data.multiply(portion, axis=0)
        
    # Calories data
    calories = grams.copy()
    calories['fat'] = calories.fat * 9
    calories['carbs'] = calories.carbs * 4
    calories['protein'] = calories.protein * 4
    calories['fiber'] = calories.fiber * 2
    
    return {'grams': grams, 'cals': calories}

# %%
# Calc grams and calories for all meals
meal_data = {meal: get_meal_data(meals[meal]) for meal in meals}

# Add gram and calorie totals
totals = {}
for measure in ['cals', 'grams']:
    pieces = []
    for meal in meal_data.keys():
        pieces.append(meal_data[meal][measure])
    total = pd.concat(pieces).groupby(level=0).sum()
    totals[measure] = total

meal_data['Total'] = totals

# %%
num_meals = len(meal_data)

fig, ax = plt.subplots(2, num_meals)

ax[0, 0].set_ylabel('Grams')
ax[1, 0].set_ylabel('Calories')

def make_autopct(values):
    def pct_labels(pct):
        if measure == 'cals':
            out =  f'{pct:.0f}%' if pct > 3 else ''
        else:
            grams = pct * total / 100
            out = f'{grams:.0f}g' if grams > 3 else ''
        return out
    return pct_labels


for col, meal in enumerate(meal_data):
    for row, measure in enumerate(['grams', 'cals']):
        
        data = meal_data[meal][measure].sum()
        total = data.sum()
        
        ax[row, col].pie(data, labels=data.index,
                         autopct=make_autopct(data))
        ax[row, col].set_xlabel(f'Total: {total:.0f} {measure}')
        
        ax[0, col].set_title(meal)
